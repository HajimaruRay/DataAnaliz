# %% [markdown]
# # 660710075 ชลธี เกิดก่อวงศ์

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#1. อ่านไฟล์ข้อมูลชื่อ flights.csv (อยู่บน facebook กลุ่่มวิชา)

# %%
fli = pd.read_csv("E:/Unitversity/Data Analiz/Lab_Week/Week4/flights.csv")

# %%
#2. แสดงผล 10 แถวแรก

# %%
fli.head(10)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
# 5  2013      1    1     558.0       -2.0     753.0        8.0      AA  N3ALAA
# 6  2013      1    1     558.0       -2.0     924.0        7.0      UA  N29129
# 7  2013      1    1     558.0       -2.0     923.0      -14.0      UA  N53441
# 8  2013      1    1     559.0       -1.0     941.0       31.0      AA  N3DUAA
# 9  2013      1    1     559.0       -1.0     854.0       -8.0      UA  N76515
#
#    flight origin dest  air_time  distance  hour  minute
# ...

# %%
#3. ข้อมูลที่อ่านมาได้มีจำนวนแถวและคอลัมน์เท่าไร

# %%
fli.shape
# Out:
# (160754, 16)

# %%
#4. แสดงผล attribute name ของ distance hour minute ตั้งแต่ แถวที่ 50 ไปอีก 20 แถว

# %%
fli.loc[50:70, ['distance','hour','minute']]
# Out:
#     distance  hour  minute
# 50      1605   7.0    27.0
# 51      1416   7.0    28.0
# 52       937   7.0    32.0
# 53       733   7.0    39.0
# 54      1400   7.0    39.0
# 55      2475   7.0    43.0
# 56      2422   7.0    43.0
# 57      2586   7.0    45.0
# 58      2565   7.0    46.0
# 59       950   7.0    52.0
# 60      1620   7.0    52.0
# 61       544   7.0    52.0
# 62      1096   7.0    53.0
# 63       762   7.0    54.0
# 64      1089   7.0    59.0
# 65      1020   8.0     0.0
# 66       187   8.0     3.0
# 67      2586   8.0     3.0
# 68       944   8.0     4.0
# 69       760   8.0     7.0
# 70      1035   8.0    10.0

# %%
#5. แสดงผลเฉพาะ attribute name ชื่อ flight

# %%
fli['flight']
# Out:
# 0         1545
# 1         1714
# 2         1141
# 3          461
# 4         1696
#           ...
# 160749     475
# 160750    2363
# 160751     185
# 160752     523
# 160753     471
# Name: flight, Length: 160754, dtype: int64

# %%
#6.แสดงผลสถิติแยกตามชื่อสนามบินที่เครื่องบินออก (origin)

# %%
fli_origin = fli.groupby(['origin'])
fli_origin.describe()
# Out:
#            year                                                         month  \
#           count    mean  std     min     25%     50%     75%     max    count
# origin
# EWR     59035.0  2013.0  0.0  2013.0  2013.0  2013.0  2013.0  2013.0  59035.0
# JFK     42013.0  2013.0  0.0  2013.0  2013.0  2013.0  2013.0  2013.0  42013.0
# LGA     59706.0  2013.0  0.0  2013.0  2013.0  2013.0  2013.0  2013.0  59706.0
#
#                   ...  hour         minute                                   \
#             mean  ...   75%   max    count       mean        std  min   25%
# origin            ...
# EWR     6.572237  ...  17.0  23.0  58385.0  30.162370  17.758978  0.0  15.0
# JFK     6.558089  ...  17.0  24.0  41702.0  31.851158  18.625436  0.0  16.0
# LGA     6.515308  ...  16.0  24.0  58331.0  34.999074  19.307334  0.0  18.0
#
#
#          50%   75%   max
# origin
# EWR     29.0  46.0  59.0
# JFK     31.0  51.0  59.0
# LGA     39.0  53.0  59.0
#
# [3 rows x 96 columns]

# %%
#7. แสดงผลค่าเฉลี่ยของระยะทางที่บิน (distance)

# %%
fli['distance'].mean()
# Out:
# 1282.4454197096184

# %%
#8. จากข้อ 7 ให้แสดงผลค่าเฉลี่ยของระยะทางที่บิน (distance) แยกตามกลุ่มเที่ยวบิน (flight)

# %%
fli_flight = fli.groupby('flight')
fli_flight[['distance']].mean()
# Out:
#            distance
# flight
# 1       2396.989924
# 3       2451.590786
# 4       1248.033445
# 5       2402.000000
# 6       1990.000000
# ...             ...
# 2594    1587.000000
# 2595    2454.000000
# 2596    2248.000000
# 2598    1089.000000
# 2599     187.000000
#
# [1820 rows x 1 columns]

# %%
#9. ผลที่ได้จากข้อ 6 ให้พิมพ์ค่าเฉลี่ยของการออกไม่ตรงเวลาของสายการบิน (hour)

# %%
fli_origin[['hour']].mean()
# Out:
#              hour
# origin
# EWR     13.028141
# JFK     13.217208
# LGA     12.375444

# %%
#10. ต้องการแสดงผลเฉพาะสนามบินปลายทางที่ชื่อ LAS

# %%
fli[fli['dest'] == "LAS"]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 9       2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 130     2013      1    1    1011.0       -4.0    1246.0      -21.0      DL
# 147     2013      1    1    1059.0        6.0    1342.0       -9.0      UA
# 255     2013      1    1    1539.0        2.0    1854.0       35.0      UA
# 265     2013      1    1    1559.0       -6.0    1844.0      -28.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160623  2013      9   30    1650.0       -4.0    1855.0      -39.0      UA
# 160631  2013      9   30    1659.0       -1.0    1915.0      -30.0      AA
# 160674  2013      9   30    1807.0       12.0    2000.0      -28.0      DL
# 160707  2013      9   30    1905.0        0.0    2103.0      -34.0      DL
# 160716  2013      9   30    1931.0       -3.0    2147.0      -39.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
#11. เพิ่มเติม ต้องการแสดงผลเฉพาะ attribute dep_delay และ arr_delay ของสนามบินปลายทางที่ชื่อ LAS

# %%
fli_destLAS = fli[fli['dest'] == "LAS"]
fli_destLAS[['dep_delay','arr_delay']]
# Out:
#         dep_delay  arr_delay
# 9            -1.0       -8.0
# 130          -4.0      -21.0
# 147           6.0       -9.0
# 255           2.0       35.0
# 265          -6.0      -28.0
# ...           ...        ...
# 160623       -4.0      -39.0
# 160631       -1.0      -30.0
# 160674       12.0      -28.0
# 160707        0.0      -34.0
# 160716       -3.0      -39.0
#
# [4322 rows x 2 columns]

# %%
#12. หาค่าเฉลี่ยของ arr_delay

# %%
fli['arr_delay'].mean()
# Out:
# 2.0945373495349116
