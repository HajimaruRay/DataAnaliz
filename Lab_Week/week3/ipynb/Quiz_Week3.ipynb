# %% [markdown]
# # 660710075 ชลธี เกิดก่อวงศ์

# %%
import numpy as np
import pandas as pd

# %%
food = pd.read_csv("E:/Unitversity/Data Analiz/Lab_Week/week3/mexican.csv")

# %%
food.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
food.sort_values(by='quantity',ascending=False)
# Out:
#       order_id  quantity                              item_name  \
# 3598      1443        15           Chips and Fresh Tomato Salsa
# 4152      1660        10                          Bottled Water
# 3887      1559         8                          Side of Chips
# 3599      1443         7                          Bottled Water
# 2441       970         5                          Bottled Water
# ...        ...       ...                                    ...
# 1592       645         1                           Chicken Bowl
# 1593       645         1  Chips and Tomatillo Green Chili Salsa
# 1594       646         1                          Carnitas Bowl
# 1595       646         1                        Chicken Burrito
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 3598                                                NaN    $44.25
# ...

# %%
food.quantity.mean()
# Out:
# 1.0757247944612722

# %%
food.size
# Out:
# 23110

# %%
food.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
food.quantity.head(20).mean(numeric_only=True)
# Out:
# 1.1

# %%
food.quantity.dtypes
# Out:
# dtype('int64')

# %%
food.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
food.quantity.max()
# Out:
# 15

# %%
food.std(numeric_only=True)
# Out:
# order_id    528.890796
# quantity      0.410186
# dtype: float64

# %%
food.quantity.min()
# Out:
# 1

# %%
food.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
food.sort_values(by = 'quantity', ascending = False, inplace = True)
food.head(30)
# Out:
#       order_id  quantity                            item_name  \
# 3598      1443        15         Chips and Fresh Tomato Salsa
# 4152      1660        10                        Bottled Water
# 3887      1559         8                        Side of Chips
# 3599      1443         7                        Bottled Water
# 2441       970         5                        Bottled Water
# 4490      1786         4                    Canned Soft Drink
# 4491      1786         4                    Canned Soft Drink
# 3602      1443         4                      Chicken Burrito
# 1425       577         4                        Bottled Water
# 4489      1786         4                  Chips and Guacamole
# 1254       511         4                      Chicken Burrito
# 1257       511         4         Chips and Fresh Tomato Salsa
# 3973      1592         4                    Canned Soft Drink
# 2235       901         4                          Canned Soda
# ...

# %%
food.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
food.shape
# Out:
# (4622, 5)
